# %% [markdown]
# ### Tables, data collection, variables

# %% [markdown]
# ###  Data sources
#
# #### Master  merged dataset for  survival
#
# -  https://brunods10.s3-us-west-2.amazonaws.com/MIT_COVID/bruno_798_patients_merged_survival_data.csv
#
# #### nCov19 is merged with the imperial college dataset above to generate our survival data:
#
# - https://brunods10.s3-us-west-2.amazonaws.com/MIT_COVID/latestdata.csv
#
#
# #### Patient-level symptoms data that include onset dates of different symptoms, hospitalization admission/recovery/death date
#
# -  https://www.imperial.ac.uk/media/imperial-college/medicine/sph/ide/gida-fellowships/subset_international_cases_2020_03_11.csv

# %%
#%sh ls /dbfs/FileStore/Tables/
#%fs ls /databricks-datasets

display(dbutils.fs.ls("/FileStore/tables/"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#dbutils.fs.help("ls")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# File location and type
file_location_bruno_patients = "dbfs:/FileStore/tables/bruno_798_patients_merged_survival_data-4.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","

## import all_vars_for_zeroinf_analysis  file 
# The applied options are for CSV files. For other file types, these will be ignored.
Bruno_patients_merged_survival = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location_bruno_patients)


# File location and type
file_location_clean_biomaker = "dbfs:/FileStore/tables/clean_biomarker_first.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

## import all_vars_for_zeroinf_analysis  file 
# The applied options are for CSV files. For other file types, these will be ignored.
Clean_biomarker_first = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location_clean_biomaker)


# File location and type
file_location_clean_biomaker_last = "dbfs:/FileStore/tables/clean_biomarker_last.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

## import all_vars_for_zeroinf_analysis  file 
# The applied options are for CSV files. For other file types, these will be ignored.
Clean_biomarker_last = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location_clean_biomaker_last)


# File location and type
file_location_clean_biomaker_mean = "dbfs:/FileStore/tables/clean_biomarker_mean.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

## import all_vars_for_zeroinf_analysis  file 
# The applied options are for CSV files. For other file types, these will be ignored.
Clean_biomarker_mean = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location_clean_biomaker_mean)


# File location and type
file_location_covid_einstein = "dbfs:/FileStore/tables/covid_einstein.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

## import all_vars_for_zeroinf_analysis  file 
# The applied options are for CSV files. For other file types, these will be ignored.
Covid_einstein = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location_covid_einstein)


# File location and type
file_location_df_dummy2 = "dbfs:/FileStore/tables/df_dummy2.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

## import all_vars_for_zeroinf_analysis  file 
# The applied options are for CSV files. For other file types, these will be ignored.
df_dummy2 = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location_df_dummy2)


# File location and type
file_location_survival_master = "dbfs:/FileStore/tables/survival_master.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

## import all_vars_for_zeroinf_analysis  file 
# The applied options are for CSV files. For other file types, these will be ignored.
survival_master = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location_survival_master)


# File location and type
file_location_survival_master_dummy = "dbfs:/FileStore/tables/survival_master_dummy.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

## import all_vars_for_zeroinf_analysis  file 
# The applied options are for CSV files. For other file types, these will be ignored.
survival_master_dummy = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location_survival_master_dummy)



# File location and type
file_location_symptoms_dictionary = "dbfs:/FileStore/tables/symptoms_dictionary.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

## import all_vars_for_zeroinf_analysis  file 
# The applied options are for CSV files. For other file types, these will be ignored.
Symptoms_dictionary = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location_symptoms_dictionary)


### dbfs:/FileStore/tables/dataset.csv

# File location and type
file_location_dataset = "dbfs:/FileStore/tables/dataset.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
Dataset = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location_dataset)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(Clean_biomarker_last)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
Clean_biomarker_last.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- PATIENT_ID: integer (nullable = true)
# -- Admission time: timestamp (nullable = true)
# -- Discharge time: timestamp (nullable = true)
# -- RE_DATE: string (nullable = true)
# -- age: integer (nullable = true)
# -- gender: integer (nullable = true)
# -- outcome: integer (nullable = true)
# -- Hypersensitive cardiac troponinI: string (nullable = true)
# -- hemoglobin: string (nullable = true)
# -- Serum chloride: string (nullable = true)
# -- Prothrombin time: string (nullable = true)
# -- procalcitonin: string (nullable = true)
# -- eosinophils(%): string (nullable = true)
# ...

# %%
Clean_biomarker_last.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
Clean_biomarker_last.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 375</div>

# %%
display(Covid_einstein)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
Covid_einstein.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Patient ID: string (nullable = true)
# -- Patient age quantile: integer (nullable = true)
# -- SARS-Cov-2 exam result: string (nullable = true)
# -- Patient addmited to regular ward (1=yes, 0=no): integer (nullable = true)
# -- Patient addmited to semi-intensive unit (1=yes, 0=no): integer (nullable = true)
# -- Patient addmited to intensive care unit (1=yes, 0=no): integer (nullable = true)
# -- Hematocrit: double (nullable = true)
# -- Hemoglobin: double (nullable = true)
# -- Platelets: double (nullable = true)
# -- Mean platelet volume : double (nullable = true)
# -- Red blood Cells: double (nullable = true)
# ...

# %%
Covid_einstein.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: 5644</div>

# %%
display(survival_master)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
survival_master.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- id: string (nullable = true)
# -- sex: string (nullable = true)
# -- age: string (nullable = true)
# -- country: string (nullable = true)
# -- symptoms: string (nullable = true)
# -- outcome: string (nullable = true)
# -- date_onset_symptoms: string (nullable = true)
# -- date_admission_hospital: string (nullable = true)
# -- date_death_or_discharge: string (nullable = true)
# -- date_confirmation: string (nullable = true)
#
# </div>

# %%
survival_master.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: 3850</div>

# %%
survival_master.select('sex','outcome').distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: 29</div>

# %%
survival_master.select('sex','outcome').show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----------+
#    sex|   outcome|
# +------+----------+
# female|discharged|
# female|      died|
#   male|      died|
# female|      died|
#   male|      died|
# +------+----------+
# only showing top 5 rows
#
# </div>

# %%
survival_master.groupby('outcome').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+
#              outcome|count|
# +--------------------+-----+
#                   NA| 3536|
#             Deceased|    3|
#                Alive|    7|
#                death|    4|
#           05.02.2020|    1|
#               stable|   23|
# treated in an int...|    1|
#            recovered|   49|
#               severe|    1|
#           discharged|  101|
# Symptoms only imp...|    1|
#                 died|   64|
#            discharge|   52|
#           Discharged|    4|
#                 dead|    1|
#            Recovered|    2|
# +--------------------+-----+
#
# </div>

# %%
#display(Dataset)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
